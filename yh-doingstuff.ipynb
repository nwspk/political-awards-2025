# %% [markdown]
# # Experimenting with data

# %% [markdown]
# ## Data exploration

# %%
import pandas as pd
scraped_df = pd.read_csv('data/grantmaking_projects_with_scraped_data.csv')
scraped_df.head()
# Out:
#                   website source_type  \
# 0     http://hatemeter.eu     website
# 1        https://12ft.io/     website
# 2  https://adhocracy.plus     website
# 3   https://aisafety.info     website
# 4   https://alaveteli.org     website
#
#                                      content_summary  \
# 0  The Hatemeter project, funded by the EU, devel...
# 1  12ft.io is a tool designed to create a cleaner...
# 2  adhocracy+ is a free, user-friendly digital de...
# 3  AI safety focuses on ensuring that artificial ...
# 4  Alaveteli, developed by mySociety, is an open-...
#
#                            screenshot_path   project_name  \
# 0    screenshots/hatemetereu_942cc7dd.jpeg      Hatemeter
# 1         screenshots/12ftio_df2d23b9.jpeg        12ft.io
# 2  screenshots/adhocracyplus_385b6629.jpeg     adhocracy+
# 3   screenshots/aisafetyinfo_efd6a671.jpeg  AISafety.info
# 4   screenshots/alaveteliorg_dbb6c2fc.jpeg      Alaveteli
#
# ...
